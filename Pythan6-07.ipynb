# %%
def add(a,b):
 print(a+b)
add(2,2)
# Out:
# 4

# %%
#calculator using function
def add(a,b):
 return(a+b)
def sub(a,b):
 return(a-b)
def multiple(a,b):
 return(a*b)
def division(a,b):
 return(a/b)
c=int(input('''Enter
   1.add
   2.sub
   3.multiple
   4.division
    '''))
num1=int(input('Num¹ '))
num2=int(input('Num² '))
if c==1:
  A=add(num1,num2)
  print(A)
elif c==2:
  B=sub(num1,num2)
  print (B)
elif c==3:
  C=multiple(num1,num2)
  print (C)
elif c==4:
  D=division(num1,num2)
  print (D)
else:
  print('ERROR')
# Out:
# Enter
#    1.add
#    2.sub
#    3.multiple
#    4.division
#     3
# Num¹ 2
# Num² 2
# 4

# %%
a=23
b=26
c=34
import math
print(math.max(a,b,c))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ba24a8d64462> in <cell line: 5>()
#       3 c=34
#       4 import math
# ----> 5 print(math.max(a,b,c))
#
# AttributeError: module 'math' has no attribute 'max'

# %%
def max(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c
max(10,20,15)
# Out:
# 20

# %%
def add(a,b):
 return(a+b)
def sub(a,b):
 return(a-b)
def multiple(a,b):
 return(a*b)
c=int(input('''Enter
   1.add
   2.sub
   3.multiple
    '''))
num1=int(input('Num¹ '))
num2=int(input('Num² '))
num3=int(input('Num³ '))
if c==1:
  A=add(num3,add(num1,num2,))
  print(A)
elif c==2:
  B=sub(num3,sun(num1,num2))
  print (B)
elif c==3:
  C=multiple(num3,multiple(num1,num2))
  print (C)
# Out:
# Enter
#    1.add
#    2.sub
#    3.multiple
#     1
# Num¹ 10
# Num² 20
# Num³ 30
# 60
